# %% [markdown]
# <a href="https://colab.research.google.com/github/Dannyrand-dev/Hendeb_project/blob/main/Assignment_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Installing essential libraries for Cheminformatics and Bioinformatics
# !pip install rdkit pandas scikit-learn pubchempy biopython
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 37.0/37.0 MB 19.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 99.4 MB/s eta 0:00:00
# ...

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

MolecularWeight_list = [250.2,490.5,320,550,186,499.9,610,505,210,163]
for Molecularweight in MolecularWeight_list:
  # Check if the individual molecular weight is 500 or lesser
  if Molecularweight <= 500:
    print(f"filtered_compounds: {Molecularweight} g/mol")
# Out:
# filtered_compounds: 250.2 g/mol
# filtered_compounds: 490.5 g/mol
# filtered_compounds: 320 g/mol
# filtered_compounds: 186 g/mol
# filtered_compounds: 499.9 g/mol
# filtered_compounds: 210 g/mol
# filtered_compounds: 163 g/mol

# %%
from rdkit import Chem
from rdkit.Chem import Descriptors

Logp_values =[1.5,4.2,0.8,5.5,2.11]
for Logpvalues in Logp_values:
  # To categorize each LogP value
  if Logpvalues >5:
    print(f"High lipophilicity-Risk of bioaccumulation at logP={Logpvalues}")
  elif 2 <= Logpvalues <= 5:
    print(f"optimal range for drug-likesness at logP={Logpvalues}")
  else:
    print(f"low lipophilicity at logP={Logpvalues}")
# Out:
# low lipophilicity at logP=1.5
# optimal range for drug-likesness at logP=4.2
# low lipophilicity at logP=0.8
# High lipophilicity-Risk of bioaccumulation at logP=5.5
# optimal range for drug-likesness at logP=2.11

# %%
# Create the dictionary
compound_dict = {"TOX1": "active","TOX2": "inactive", "TOX3": "active"}
# Ask user for input
user_input = input("Enter a compound ID: ")
# Check if the ID exists in the dictionary
if user_input in compound_dict:
    print(f"{user_input} is {compound_dict[user_input]}")
else:
    print(f"{user_input} not found")
# Out:
# Enter a compound ID: TOX5
# TOX5 not found
